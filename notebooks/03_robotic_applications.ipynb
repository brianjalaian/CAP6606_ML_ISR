# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/brianjalaian/CAP6606_ml_for_intelligent_systems/blob/main/notebooks/03_robotic_applications.ipynb)
#
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/brianjalaian/CAP6606_ml_for_intelligent_systems/blob/main/notebooks/03_robotic_applications.ipynb)
#
# # Robotics Applications
#
# Integrating learned models into robotics pipelines.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the motivation for the topic
# - Review key mathematical foundations
# - Connect concepts to intelligent systems

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
data = np.random.normal(size=(3, 3))
pd.DataFrame(data, columns=['feature_1', 'feature_2', 'feature_3'])

# %% [markdown]
# ## Next Steps
#
# Continue exploring the companion reading in the course book and experiment with the code in a GPU environment.
